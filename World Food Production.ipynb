# %% [markdown]
# # World Food Production

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
d = pd.read_csv("worldfoodproduction.csv")

# %%
df = pd.DataFrame(d)
df.head()
# Out:
#         Entity  Year  Maize Production (tonnes)  Rice  Production ( tonnes)  \
# 0  Afghanistan  1961                   700000.0                    319000.0
# 1  Afghanistan  1962                   700000.0                    319000.0
# 2  Afghanistan  1963                   713000.0                    319000.0
# 3  Afghanistan  1964                   720000.0                    380000.0
# 4  Afghanistan  1965                   720000.0                    380000.0
#
#    Yams  Production (tonnes)  Wheat Production (tonnes)  \
# 0                  7467702.0                  2279000.0
# 1                  7420515.0                  2279000.0
# 2                  8479074.0                  1947000.0
# 3                  9113779.0                  2230000.0
# 4                 10067913.0                  2282000.0
#
#    Tomatoes Production (tonnes)  Tea  Production ( tonnes )  \
# 0                     1873812.0                     56315.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11912 entries, 0 to 11911
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Entity                               11912 non-null  object
#  1   Year                                 11912 non-null  int64
#  2   Maize Production (tonnes)            11912 non-null  float64
#  3   Rice  Production ( tonnes)           11912 non-null  float64
#  4   Yams  Production (tonnes)            11912 non-null  float64
#  5   Wheat Production (tonnes)            11912 non-null  float64
#  6   Tomatoes Production (tonnes)         11912 non-null  float64
#  7   Tea  Production ( tonnes )           11912 non-null  float64
#  8   Sweet potatoes  Production (tonnes)  11912 non-null  float64
#  9   Sunflower seed  Production (tonnes)  11912 non-null  float64
#  10  Sugar cane Production (tonnes)       11912 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Entity                                 0
# Year                                   0
# Maize Production (tonnes)              0
# Rice  Production ( tonnes)             0
# Yams  Production (tonnes)              0
# Wheat Production (tonnes)              0
# Tomatoes Production (tonnes)           0
# Tea  Production ( tonnes )             0
# Sweet potatoes  Production (tonnes)    0
# Sunflower seed  Production (tonnes)    0
# Sugar cane Production (tonnes)         0
# Soybeans  Production (tonnes)          0
# Rye  Production (tonnes)               0
# Potatoes  Production (tonnes)          0
# Oranges  Production (tonnes)           0
# Peas, dry Production ( tonnes)         0
# Palm oil  Production (tonnes)          0
# Grapes  Production (tonnes)            0
# Coffee, green Production ( tonnes)     0
# Cocoa beans Production (tonnes)        0
# Meat, chicken  Production (tonnes)     0
# Bananas  Production ( tonnes)          0
# Avocados Production (tonnes)           0
# ...

# %%
df.columns
# Out:
# Index(['Entity', 'Year', 'Maize Production (tonnes)',
#        'Rice  Production ( tonnes)', 'Yams  Production (tonnes)',
#        'Wheat Production (tonnes)', 'Tomatoes Production (tonnes)',
#        'Tea  Production ( tonnes )', 'Sweet potatoes  Production (tonnes)',
#        'Sunflower seed  Production (tonnes)', 'Sugar cane Production (tonnes)',
#        'Soybeans  Production (tonnes)', 'Rye  Production (tonnes)',
#        'Potatoes  Production (tonnes)', 'Oranges  Production (tonnes)',
#        'Peas, dry Production ( tonnes)', 'Palm oil  Production (tonnes)',
#        'Grapes  Production (tonnes)', 'Coffee, green Production ( tonnes)',
#        'Cocoa beans Production (tonnes)', 'Meat, chicken  Production (tonnes)',
#        'Bananas  Production ( tonnes)', 'Avocados Production (tonnes)',
#        'Apples Production (tonnes)'],
#       dtype='object')

# %%
df.tail()
# Out:
#          Entity  Year  Maize Production (tonnes)  Rice  Production ( tonnes)  \
# 11907  Zimbabwe  2017                  1532572.0                 20502618.00
# 11908  Zimbabwe  2018                  1560100.0                 31871776.60
# 11909  Zimbabwe  2019                   773976.0                  3382151.40
# 11910  Zimbabwe  2020                  1202347.0                  3535631.80
# 11911  Zimbabwe  2021                  1469664.0                  7575899.96
#
#        Yams  Production (tonnes)  Wheat Production (tonnes)  \
# 11907                 267360.800                30991516.16
# 11908                 266749.800                16884482.98
# 11909                 479002.206                64989733.20
# 11910                 743761.226                43020887.20
# 11911                1153262.800                 1316724.80
#
#        Tomatoes Production (tonnes)  Tea  Production ( tonnes )  \
# 11907                    324020.864                     83904.6
# ...

# %%
df.shape
# Out:
# (11912, 24)

# %%
df['Entity'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Africa (FAO)', 'Albania', 'Algeria',
#        'Americas (FAO)', 'Angola', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Asia', 'Asia (FAO)', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belgium-Luxembourg (FAO)', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Cape Verde', 'Caribbean (FAO)',
#        'Central African Republic', 'Central America (FAO)',
#        'Central Asia (FAO)', 'Chad', 'Chile', 'China', 'China (FAO)',
#        'Colombia', 'Comoros', 'Congo', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Czechia', 'Czechoslovakia',
#        'Democratic Republic of Congo', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'East Timor', 'Eastern Africa (FAO)',
# ...

# %%
df['Year'].unique()
# Out:
# array([1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021], dtype=int64)

# %% [markdown]
# # Statiscal Analysis

# %%
df.describe()
# Out:
#                Year  Maize Production (tonnes)  Rice  Production ( tonnes)  \
# count  11912.000000               1.191200e+04                1.191200e+04
# mean    1992.115346               1.926434e+07                2.254542e+07
# std       17.606091               7.028022e+07                7.749779e+07
# min     1961.000000               0.000000e+00                0.000000e+00
# 25%     1977.000000               2.379300e+04                3.902475e+04
# 50%     1993.000000               4.000490e+05                4.543745e+05
# 75%     2007.000000               4.979875e+06                4.440542e+06
# max     2021.000000               1.210235e+09                7.872939e+08
#
#        Yams  Production (tonnes)  Wheat Production (tonnes)  \
# count               1.191200e+04               1.191200e+04
# mean                2.744973e+06               2.365684e+07
# std                 8.787786e+06               6.177899e+07
# ...

# %%
df.corr()
# Out:
#                                          Year  Maize Production (tonnes)  \
# Year                                 1.000000                   0.114699
# Maize Production (tonnes)            0.114699                   1.000000
# Rice  Production ( tonnes)           0.023383                   0.116212
# Yams  Production (tonnes)            0.038001                  -0.040265
# Wheat Production (tonnes)            0.033364                   0.064592
# Tomatoes Production (tonnes)         0.050889                   0.100181
# Tea  Production ( tonnes )           0.042265                  -0.044442
# Sweet potatoes  Production (tonnes)  0.000194                  -0.057627
# Sunflower seed  Production (tonnes) -0.016813                   0.040035
# Sugar cane Production (tonnes)       0.000835                  -0.064108
# Soybeans  Production (tonnes)        0.022579                   0.026176
# Rye  Production (tonnes)             0.004240                   0.115834
# ...

# %% [markdown]
# # Data Visualizations

# %%
x = df['Maize Production (tonnes)']
y = df['Tomatoes Production (tonnes)']
plt.scatter(x, y)
plt.xlabel("Maize Production (tonnes)")
plt.ylabel("Rice Production (tonnes)")
plt.title("Maize vs Rice Production")
plt.show()

# %%
x = df['Entity']
y = df['Tomatoes Production (tonnes)']
plt.scatter(x, y)
plt.xlabel('Entity')
plt.ylabel('Tomatoes Production (tonnes)')
plt.title("Production")
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Entity', 'Year', 'Maize Production (tonnes)',
#        'Rice  Production ( tonnes)', 'Yams  Production (tonnes)',
#        'Wheat Production (tonnes)', 'Tomatoes Production (tonnes)',
#        'Tea  Production ( tonnes )', 'Sweet potatoes  Production (tonnes)',
#        'Sunflower seed  Production (tonnes)', 'Sugar cane Production (tonnes)',
#        'Soybeans  Production (tonnes)', 'Rye  Production (tonnes)',
#        'Potatoes  Production (tonnes)', 'Oranges  Production (tonnes)',
#        'Peas, dry Production ( tonnes)', 'Palm oil  Production (tonnes)',
#        'Grapes  Production (tonnes)', 'Coffee, green Production ( tonnes)',
#        'Cocoa beans Production (tonnes)', 'Meat, chicken  Production (tonnes)',
#        'Bananas  Production ( tonnes)', 'Avocados Production (tonnes)',
#        'Apples Production (tonnes)'],
#       dtype='object')

# %%
print(df["Maize Production (tonnes)"])
# Out:
# 0         700000.0
# 1         700000.0
# 2         713000.0
# 3         720000.0
# 4         720000.0
#            ...
# 11907    1532572.0
# 11908    1560100.0
# 11909     773976.0
# 11910    1202347.0
# 11911    1469664.0
# Name: Maize Production (tonnes), Length: 11912, dtype: float64

# %%
df1 = df.drop(columns=[
    'Yams  Production (tonnes)',
    'Sunflower seed  Production (tonnes)',
    'Soybeans  Production (tonnes)',
    'Rye  Production (tonnes)',
    'Peas, dry Production ( tonnes)',
    'Palm oil  Production (tonnes)',
    'Coffee, green Production ( tonnes)',
    'Cocoa beans Production (tonnes)',
    'Meat, chicken  Production (tonnes)','Tea  Production ( tonnes )', 'Sweet potatoes  Production (tonnes)'])

# %% [markdown]
# # Df1

# %%
df1.head()
# Out:
#         Entity  Year  Maize Production (tonnes)  Rice  Production ( tonnes)  \
# 0  Afghanistan  1961                   700000.0                    319000.0
# 1  Afghanistan  1962                   700000.0                    319000.0
# 2  Afghanistan  1963                   713000.0                    319000.0
# 3  Afghanistan  1964                   720000.0                    380000.0
# 4  Afghanistan  1965                   720000.0                    380000.0
#
#    Wheat Production (tonnes)  Tomatoes Production (tonnes)  \
# 0                  2279000.0                     1873812.0
# 1                  2279000.0                     2044797.0
# 2                  1947000.0                     2096077.0
# 3                  2230000.0                     2388264.0
# 4                  2282000.0                     2559608.0
#
#    Sugar cane Production (tonnes)  Potatoes  Production (tonnes)  \
# 0                         45000.0                       130000.0
# ...

# %%
df1.shape
# Out:
# (11912, 13)

# %%
features = df1.columns

# %% [markdown]
# # Data cleaning and processing

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df1['Entity'] = label_encoder.fit_transform(df['Entity'])
df1
# Out:
#        Entity  Year  Maize Production (tonnes)  Rice  Production ( tonnes)  \
# 0           0  1961                   700000.0                   319000.00
# 1           0  1962                   700000.0                   319000.00
# 2           0  1963                   713000.0                   319000.00
# 3           0  1964                   720000.0                   380000.00
# 4           0  1965                   720000.0                   380000.00
# ...       ...   ...                        ...                         ...
# 11907     225  2017                  1532572.0                 20502618.00
# 11908     225  2018                  1560100.0                 31871776.60
# 11909     225  2019                   773976.0                  3382151.40
# 11910     225  2020                  1202347.0                  3535631.80
# 11911     225  2021                  1469664.0                  7575899.96
#
#        Wheat Production (tonnes)  Tomatoes Production (tonnes)  \
# ...

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test = train_test_split(df1, test_size=0.2, random_state=42)

# %% [markdown]
# # Data Noarmalization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df1_scaled = scaler.fit_transform(df1)

# %%
df1_scaled.shape
# Out:
# (11912, 13)

# %%
# from sklearn.cluster import KMeans


# num_clusters = 20  
# kmeans = KMeans(n_clusters=num_clusters, random_state=42)


# kmeans.fit(df1_scaled)

# %%
# kmeans.cluster_centers_

# %%
# kmeans.inertia_

# %%
# Create a StandardScaler object
scaler = StandardScaler()

# Fit and transform the data
df1_scaled = scaler.fit_transform(df1)

# Convert the scaled array back to a DataFrame
df1_scaled = pd.DataFrame(df1_scaled, columns=df1.columns)

# Check if the column names match
if all(df1.columns == df1_scaled.columns):
    print("Column names match between df1 and df1_scaled.")
else:
    print("Column names do not match between df1 and df1_scaled.")
# Out:
# Column names match between df1 and df1_scaled.

# %%
# Convert the scaled array back to a DataFrame
df1_scaled = pd.DataFrame(df1_scaled, columns=df1.columns)

# Access the column names
column_names = df1_scaled.columns
print("Column names:", column_names)
# Out:
# Column names: Index(['Entity', 'Year', 'Maize Production (tonnes)',
#        'Rice  Production ( tonnes)', 'Wheat Production (tonnes)',
#        'Tomatoes Production (tonnes)', 'Sugar cane Production (tonnes)',
#        'Potatoes  Production (tonnes)', 'Oranges  Production (tonnes)',
#        'Grapes  Production (tonnes)', 'Bananas  Production ( tonnes)',
#        'Avocados Production (tonnes)', 'Apples Production (tonnes)'],
#       dtype='object')

# %% [markdown]
# # Advance Analysis using ML Algoritms

# %%
# from sklearn.cluster import KMeans
# sse = []
# for k in range(1, 22):
#     kmeans = KMeans(n_clusters=k, random_state=42)
#     kmeans.fit(df1_scaled)
#     sse.append(kmeans.inertia_)

# plt.figure(figsize=(10, 6))
# plt.plot(range(1, 22), sse, marker='o')
# plt.xlabel('Number of clusters')
# plt.ylabel('Sum of Squared Distances (SSE)')
# plt.title('Elbow Method for Optimal k')
# plt.show()

# k_optimal = 4

# kmeans = KMeans(n_clusters=k_optimal, random_state=42)
# kmeans.fit(df1_scaled)

# df1['Cluster'] = kmeans.labels_

# print(df1.head())

# sn.pairplot(df1, hue='Cluster', vars=features, palette='tab10')
# plt.show()

# %%
from sklearn.cluster import KMeans
sse = []
for k in range(1,40):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df1_scaled)
    sse.append(kmeans.inertia_)

# %%
sn.set()
plt.figure(figsize=(6, 6))
plt.plot(range(1, 40), sse, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Sum of Squared Distances (SSE)')
plt.title('Elbow Method for Optimal k')
plt.show()

# %%
colors = ['red', 'blue', 'green', 'cyan', 'magenta', 'yellow', 'black', 'orange', 'purple', 'brown', 'pink', 'gray', 'olive', 'lime', 'navy']

# Create a grid of subplots for each pair of features
fig, axs = plt.subplots(13, 13, figsize=(20, 20))

# Loop through each pair of features and each cluster
for i in range(13):
    for j in range(13):
        # Plot each cluster with a different color
        for cluster_id in range(15):
            axs[i, j].scatter(df1_scaled[y == cluster_id, i], df1_scaled[y == cluster_id, j], s=10, c=colors[cluster_id], label=f'cluster{cluster_id+1}')
        axs[i, j].set_xlabel(f'Feature {i+1}')
        axs[i, j].set_ylabel(f'Feature {j+1}')
        axs[i, j].legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11907    False
# 11908    False
# 11909    False
# 11910    False
# 11911    False
# Name: Tomatoes Production (tonnes), Length: 11912, dtype: bool, 0)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
kmeans = KMeans(n_clusters=15,init="k-means++",random_state=0)
y = kmeans.fit_predict(df1_scaled)
print(y)

# %%
np.set_printoptions(threshold=np.inf)
print(y)

# %%
plt.figure(figsize=(8,8))
plt.scatter(df1_scaled[y==0,0],df1_scaled[y==0,1],s=50,c='green',label='cluster1')
plt.scatter(df1_scaled[y==1,0],df1_scaled[y==1,1],s=50,c='green',label='cluster2')
plt.scatter(df1_scaled[y==2,0],df1_scaled[y==2,1],s=50,c='green',label='cluster3')
plt.scatter(df1_scaled[y==3,0],df1_scaled[y==3,1],s=50,c='green',label='cluster4')
plt.scatter(df1_scaled[y==4,0],df1_scaled[y==4,1],s=50,c='green',label='cluster5')
plt.scatter(df1_scaled[y==5,0],df1_scaled[y==5,1],s=50,c='green',label='cluster6')
plt.scatter(df1_scaled[y==6,0],df1_scaled[y==6,1],s=50,c='green',label='cluster7')
plt.scatter(df1_scaled[y==7,0],df1_scaled[y==7,1],s=50,c='green',label='cluster8')
plt.scatter(df1_scaled[y==8,0],df1_scaled[y==8,1],s=50,c='green',label='cluster9')
plt.scatter(df1_scaled[y==9,0],df1_scaled[y==9,1],s=50,c='green',label='cluster10')
plt.scatter(df1_scaled[y==10,0],df1_scaled[y==10,1],s=50,c='green',label='cluster11')
plt.scatter(df1_scaled[y==11,0],df1_scaled[y==11,1],s=50,c='green',label='cluster12')
plt.scatter(df1_scaled[y==12,0],df1_scaled[y==12,1],s=50,c='green',label='cluster13')
plt.scatter(df1_scaled[y==13,0],df1_scaled[y==13,1],s=50,c='green',label='cluster14')
plt.scatter(df1_scaled[y==14,0],df1_scaled[y==14,1],s=50,c='green',label='cluster15')

# %%
colors = ['red', 'blue', 'green', 'cyan', 'magenta', 'yellow', 'black', 'orange', 'purple', 'brown', 'pink', 'gray', 'olive', 'lime', 'navy']

# Plot each cluster with a different color
for i in range(15):
    plt.scatter(df1_scaled[y == i, 0], df1_scaled[y == i, 1], s=50, c=colors[i])

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-Means Clustering')
plt.show()

# %%
import matplotlib.pyplot as plt

# List of colors to use for the clusters
colors = ['red', 'blue', 'green', 'cyan', 'magenta', 'yellow', 'black', 'orange', 'purple', 'brown', 'pink', 'gray', 'olive', 'lime', 'navy']

# Plot each cluster with a different color
plt.figure(figsize=(10, 6))

# Choose two features for the scatter plot. Here, using the first two columns as an example.
feature_x_index = 0
feature_y_index = 1

for i in range(15):
    plt.scatter(df1_scaled[y == i, feature_x_index], df1_scaled[y == i, feature_y_index], s=50, c=colors[i], label=f'Cluster {i+1}')

plt.xlabel(f'Feature {feature_x_index + 1}')
plt.ylabel(f'Feature {feature_y_index + 1}')
plt.title('K-Means Clustering')
plt.legend()
plt.show()

# %%
k_optimal = 15

kmeans = KMeans(n_clusters=k_optimal, random_state=42)
kmeans.fit(df1_scaled)

df1['Cluster'] = kmeans.labels_

print(df1.head())

sn.pairplot(df1, hue='Cluster', vars=features, palette='tab10')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Reduce dimensionality to 2 dimensions using PCA
pca = PCA(n_components=2)
df1_pca = pca.fit_transform(df1_scaled)

# List of colors to use for the clusters
colors = ['red', 'blue', 'green', 'cyan', 'magenta', 'yellow', 'black', 'orange', 'purple', 'brown', 'pink', 'gray', 'olive', 'lime', 'navy']

# Plot each cluster with a different color
plt.figure(figsize=(8, 8))
for cluster_id in range(15):
    plt.scatter(df1_pca[y==cluster_id, 0], df1_pca[y==cluster_id, 1], s=50, c=colors[cluster_id], label=f'cluster{cluster_id+1}')

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-Means Clustering with 15 Clusters (PCA Visualization)')
plt.legend()
plt.show()
